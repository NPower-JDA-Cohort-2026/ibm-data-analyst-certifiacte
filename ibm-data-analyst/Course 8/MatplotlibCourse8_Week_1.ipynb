# %% [markdown]
# # VISUALIZATION WITH MATPLOT LIB

# %% [markdown]
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible.
#
# Matplotlib library is used for creating static, animated,
# and interactive 2D- plots or figures in Python. It can
# be installed using the following pip command from the
# command prompt:
#
# pip install matplotlib
#
# For plotting using Matplotlib, we need to import its
# Pyplot module using the following command:
#
# import matplotlib.pyplot as plt
#
# Here, plt is an alias or an alternative name for
# matplotlib.pyplot. We can use any other alias also.

# %%
#importing matplotlib

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
print('Matplotlib version: ', mpl.__version__)  # >= 2.0.0
# Out:
# Matplotlib version:  3.10.0

# %%
#setting styles
# We will use the plt.style directive to choose appropriate aesthetic styles for our figures. Here we will set the
# classic style, which ensures that the plots we create use the classic Matplotlib style:

plt.style.use('classic')

# For more information on stylesheets, see Customizing Matplotlib: Configurations and Style Sheets.

# %%
print(plt.style.available)
mpl.style.use(['ggplot']) # optional: for ggplot-like style
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
apple_SP=[34.6,65.8,76.5,88.9,78.2]
MS_SP=[67.6,74.8,70.4,77.9,83.2]
year=[2014,2015,2016,2017,2018]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(year,apple_SP)
plt.xlim((2010,2019))
plt.ylim((20,100))
plt.xticks(year ,[2014,2015,2016,2017,2018])
# #plt.show()

plt.scatter(year,MS_SP)
plt.show()

# %% [markdown]
# **Customization of a plot**
#
# grid([b, which, axis]) Configure the grid lines.
#
# legend(\*args, \*\*kwargs) Place a legend on the axes.
#
# savefig(\*args, \*\*kwargs) Save the current figure.
#
# show(\*args, \*\*kw) Display all figures.
#
# title(label[, fontdict, loc, pad]) Set a title for the axes.
#
# xlabel(xlabel[, fontdict, labelpad]) Set the label for the x-axis.
#
# xticks([ticks, labels]) Get or set the current tick locations and labels of the x-axis.
#
# ylabel(ylabel[, fontdict, labelpad]) Set the label for the y-axis.
#
# yticks([ticks, labels]) Get or set the current tick locations and labels of the y-axis.

# %%
import matplotlib.pyplot as plt
date=["25/12","26/12","27/12"]
temp=[8.5,10.5,6.8]
plt.plot(date, temp)
plt.xlabel("Date") #add the Label on x-axis
plt.ylabel("Temperature") #add the Label on y-axis
plt.title("Date wise Temperature") #add the title to the chart
plt.grid(True) #add gridlines to the background
plt.yticks(temp)
plt.show()

# %% [markdown]
# ![matplot.png](data:image/png;base64,...)

# %% [markdown]
# Colors
#
# Character Colour
#
# ‘b’ blue
#
# ‘g’ green
#
# ‘r’ red
#
# ‘c’ cyan
#
# ‘m’ magenta
#
# ‘y’ yellow
#
# ‘k’ black
#
# ‘w’ white

# %%
import matplotlib.pyplot as plt
import pandas as pd
height=[121.9,124.5,129.5,134.6,139.7,147.3,152.4,157.5,162.6]
weight=[19.7,21.3,23.5,25.9,28.5,32.1,35.7,39.6,43.2]
df=pd.DataFrame({"height":height,"weight":weight})
#Set xlabel for the plot
plt.xlabel('Weight in kg')
#Set ylabel for the plot
plt.ylabel('Height in cm')
#Set chart title:

plt.title('Average weight with respect to average height')
#plot using marker'-*' and line colour as green
plt.plot(df.weight,df.height,marker='*',markersize=10,color='green',linewidth=2, linestyle='dashdot')
plt.show()

# %% [markdown]
# **Plotting in pandas**
#
# Fortunately, pandas has a built-in implementation of Matplotlib that we can use. Plotting in pandas is as simple as appending a .plot() method to a series or dataframe.
#
# we learnt that the plot()
#
# function of the pyplot module of matplotlib can be used
# to plot a chart. However, starting from version 0.17.0,
# Pandas objects Series and DataFrame come equipped
# with their own .plot() methods. This plot() method is just
# a simple wrapper around the plot() function of pyplot.

# %% [markdown]
# Arguments accepted by kind for different plots
# kind = Plot type
#
# line Line plot (default)
#
# bar Vertical bar plot
#
# barh Horizontal bar plot
#
# hist Histogram
#
# box Boxplot
#
# area Area plot
#
# pie Pie plot
#
# scatter Scatter plo

# %%
import pandas as pd
apple_SP=[34.6,65.8,76.5,88.9,78.2]
MS_SP=[67.6,74.8,70.4,77.9,83.2]
year=[2014,2015,2016,2017,2018]

df=pd.DataFrame(list(zip(apple_SP,MS_SP,year)),columns=['Stock Price Apple','Stock Price MS','Year'])
df
# Out:
#    Stock Price Apple  Stock Price MS  Year
# 0               34.6            67.6  2014
# 1               65.8            74.8  2015
# 2               76.5            70.4  2016
# 3               88.9            77.9  2017
# 4               78.2            83.2  2018

# %%
plt.barh(df['Year'],df['Stock Price Apple'])
# Out:
# <BarContainer object of 5 artists>

# %%
df.plot(kind='bar')
# Out:
# <Axes: >

# %%
df.plot(kind='bar', title= "multi-column DataFrame")
# Out:
# <Axes: title={'center': 'multi-column DataFrame'}>

# %%
df.set_index('Year', inplace=True)
df
# tip: The opposite of set is reset. So to reset the index, we can use df_can.reset_index()
# Out:
#       Stock Price Apple  Stock Price MS
# Year
# 2014               34.6            67.6
# 2015               65.8            74.8
# 2016               76.5            70.4
# 2017               88.9            77.9
# 2018               78.2            83.2

# %%
df.plot(stacked=True,kind='bar', title= " a multi-column DataFrame");

# %%
plt.plot(year,apple_SP,'--g', year,MS_SP)
# plt.plot(year,MS_SP)
plt.xlabel("year")
plt.ylabel("Stock Price")
plt.show()

# %%
plt.plot(year,apple_SP,'k',year,MS_SP,'--g')
#plt.scatter(year,MS_SP)
plt.xlabel("year")
plt.ylabel("Stock Price")
plt.axis([2013,2019,20,100],[20,40,60,80,100])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-4e635b7ec5d5> in <cell line: 5>()
#       3 plt.xlabel("year")
#       4 plt.ylabel("Stock Price")
# ----> 5 plt.axis([2013,2019,20,100],[20,40,60,80,100])
#       6 plt.show()
#
# TypeError: axis() takes from 0 to 1 positional arguments but 2 were given

# %% [markdown]
# **Subplots**

# %%
import pandas as pd
apple_SP=[34.6,65.8,76.5,88.9,78.2]
MS_SP=[67.6,74.8,70.4,77.9,83.2]
year=[2014,2015,2016,2017,2018]

df=pd.DataFrame(list(zip(apple_SP,MS_SP,year)),columns=['Stock Price Apple','Stock Price MS','Year'])
df

fig_1=plt.figure(figsize=(10,12))

chart1=fig_1.add_subplot(2,3,1)
chart2=fig_1.add_subplot(2,3,2)
chart3=fig_1.add_subplot(2,3,4)
chart4=fig_1.add_subplot(2,3,3)
chart5=fig_1.add_subplot(2,3,5)


chart1.plot(year,apple_SP)
chart2.scatter(year,MS_SP)
chart3.plot(year,apple_SP)
chart4.bar(year,MS_SP)
chart5.bar(year,apple_SP)


#add_subplot(rows, cols, index) divides the figure into a grid of 2 rows × 3 columns = 6 total slots.
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# argsint, (int, int, index), or SubplotSpec, default: (1, 1, 1)
# The position of the subplot described by one of
#
# Three integers (nrows, ncols, index). The subplot will take the index position on a grid with nrows rows and ncols columns. index starts at 1 in the upper left corner and increases to the right. index can also be a two-tuple specifying the (first, last) indices (1-based, and including last) of the subplot, e.g., fig.add_subplot(3, 1, (1, 2)) makes a subplot that spans the upper 2/3 of the figure.
#
# A 3-digit integer. The digits are interpreted as if given separately as three single-digit integers, i.e. fig.add_subplot(235) is the same as fig.add_subplot(2, 3, 5). Note that this can only be used if there are no more than 9 subplots.

# %%
fig_2,axes=plt.subplots(3,2,figsize=(12,4.8))
axes[0,0].plot(year,apple_SP)
axes[0,1].plot(year,MS_SP)
axes[1,0].scatter(year,apple_SP)
axes[1,1].scatter(year,MS_SP)
axes[2,0].scatter(year,apple_SP)

# %%
df.plot(kind='box')
# Out:
# <Axes: >

# %%
plt.boxplot(MS_SP)
plt.show()

# %% [markdown]
# **squished x-axis labels by using long names and not enough space. Try running this first as-is, and then apply fixes like plt.xticks(rotation=...), plt.tight_layout(), or increase figsize.**

# %%
import matplotlib.pyplot as plt

# Sample data with long labels
categories = [
    'January Sales', 'February Sales', 'March Sales', 'April Sales',
    'May Sales', 'June Sales', 'July Sales', 'August Sales',
    'September Sales', 'October Sales', 'November Sales', 'December Sales'
]
values = [120, 150, 170, 130, 160, 140, 180, 190, 170, 200, 210, 220]

# Intentionally small figure to cause squished labels
plt.figure(figsize=(6, 4))
plt.bar(categories, values)

plt.title('Monthly Sales in 2024')
plt.xlabel('Month')
plt.ylabel('Sales')

# Show chart with squished x-axis labels
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data with long labels
categories = [
    'January Sales', 'February Sales', 'March Sales', 'April Sales',
    'May Sales', 'June Sales', 'July Sales', 'August Sales',
    'September Sales', 'October Sales', 'November Sales', 'December Sales'
]
values = [120, 150, 170, 130, 160, 140, 180, 190, 170, 200, 210, 220]

# Increased figure size to give more space
plt.figure(figsize=(12, 6))

# Create the bar chart
plt.bar(categories, values)

# Add labels and title
plt.title('Monthly Sales in 2024')
plt.xlabel('Month')
plt.ylabel('Sales')

# Rotate x-axis labels so they don’t overlap
plt.xticks(rotation=45)

# Automatically adjust spacing to prevent label cutoff
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# df.plot:
#
# Built-in Convenience: Automatically uses the DataFrame's index for the x-axis and its columns for the y-axis.
#
# Quick Visualization: Ideal for rapid, exploratory plots without much customization.
#
# Pandas Integration: Leverages Pandas features like handling missing values and labels.
#
# plt.plot:
#
# Lower-Level Control: Part of Matplotlib, offering detailed customization of every plot element.
#
# Manual Data Handling: Requires you to explicitly define the data for x and y axes.
#
# Flexibility: Better for complex visualizations and fine-tuning plot details.
