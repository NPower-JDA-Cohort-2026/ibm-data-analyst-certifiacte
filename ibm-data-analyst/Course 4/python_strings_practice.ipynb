# %% [markdown]
# # Python Strings — Practice Exercises
#
# Based on your class notebook (`Sstring_Class2`). Covers:
# - Quotes (single, double, triple) & multiline strings
# - String repetition
# - Indexing & slicing
# - Immutability
# - Concatenation & iteration
# - String methods (strip, case, replace, count, startswith/endswith, split, find, is* checks)
# - The `in` operator
#
# Fill in each `# YOUR CODE HERE` cell, then run the check cell right below it. If you see "Correct!", you got it right.

# %% [markdown]
# ## Q1: Quotes
#
# Create a variable `sentence` holding this text **without using any backslash escapes**:
#
# > She said "Python is fun"
#
# Hint: pick single vs. double quotes to avoid escaping.

# %%
# YOUR CODE HERE
sentence = None

# %%
expected = 'She said "Python is fun"'
assert sentence == expected, f"Expected: {expected!r}, got: {sentence!r}"
print("Correct! Q1 passed.")

# %% [markdown]
# ## Q2: Triple-Quoted Multiline String
#
# Using triple quotes, create `multi_line` containing (with a real newline, not typed `\n`):
# ```
# Python for
# Data Science
# ```

# %%
# YOUR CODE HERE
multi_line = None

# %%
expected = "Python for\nData Science"
assert multi_line == expected, f"Expected: {expected!r}, got: {multi_line!r}"
print("Correct! Q2 passed.")

# %% [markdown]
# ## Q3: Backslash Line Continuation
#
# Just like the class example (`"Hello. My name is Geetu.\` + newline + `I teach Python"`), use a backslash to write a single-line string across two lines of code that results in:
# ```
# Hello. My name is Python.I love data
# ```
# (one continuous line, no `\n` in the result).

# %%
# YOUR CODE HERE
continued_string = None

# %%
expected = "Hello. My name is Python.I love data"
assert continued_string == expected, f"Expected: {expected!r}, got: {continued_string!r}"
print("Correct! Q3 passed.")

# %% [markdown]
# ## Q4: String Repetition
#
# Like `mystr2 = 'Woohoo '` repeated 5 times in class, create `repeated` by repeating the word `'Data'` 3 times (result: `'DataDataData'`).

# %%
# YOUR CODE HERE
repeated = None

# %%
expected = "DataDataData"
assert repeated == expected, f"Expected: {expected!r}, got: {repeated!r}"
print("Correct! Q4 passed.")

# %% [markdown]
# ## Q5: Indexing
#
# Given `course = "Python for Data Science"`, print the character at **index 5** using zero-based indexing.

# %%
course = "Python for Data Science"

# YOUR CODE HERE
char_at_5 = None

# %%
assert char_at_5 == course[5], f"Expected: {course[5]!r}, got: {char_at_5!r}"
print("Correct! Q5 passed.")

# %% [markdown]
# ## Q6: Negative Indexing
#
# Get the **last character** of `course` using negative indexing (don't count the length manually).

# %%
# YOUR CODE HERE
last_char = None

# %%
assert last_char == course[-1], f"Expected: {course[-1]!r}, got: {last_char!r}"
print("Correct! Q6 passed.")

# %% [markdown]
# ## Q7: Slicing
#
# From `course`, extract just the word `"Data"` using slicing (`course[start:end]`).

# %%
# YOUR CODE HERE
data_word = None

# %%
expected = "Data"
assert data_word == expected, f"Expected: {expected!r}, got: {data_word!r}"
print("Correct! Q7 passed.")

# %% [markdown]
# ## Q8: Slicing — Reverse a String
#
# Just like `strdata[::-1]` in class, reverse `course` using slicing and store it in `reversed_course`.

# %%
# YOUR CODE HERE
reversed_course = None

# %%
assert reversed_course == course[::-1], f"Expected: {course[::-1]!r}, got: {reversed_course!r}"
print("Correct! Q8 passed.")

# %% [markdown]
# ## Q9: Slicing with Step
#
# From `course`, get every 2nd character starting from index 0 (like `strdata[2::2]` in class, but starting at 0 here) and store it in `every_other`.

# %%
# YOUR CODE HERE
every_other = None

# %%
assert every_other == course[0::2], f"Expected: {course[0::2]!r}, got: {every_other!r}"
print("Correct! Q9 passed.")

# %% [markdown]
# ## Q10: Immutability
#
# In class, this line raised an error:
# ```python
# strdata[0:5] = 'HOLAA'
# ```
# Without running code that raises an error, set the variable `error_type` (as a **string**, e.g. `"ValueError"`) to the name of the exception type that this line would raise.

# %%
# YOUR CODE HERE
error_type = None

# %%
assert error_type == "TypeError", f"Expected: 'TypeError', got: {error_type!r}"
print("Correct! Q10 passed. (Strings are immutable, so item assignment raises a TypeError.)")

# %% [markdown]
# ## Q11: Concatenation
#
# Like `s3 = s1 + s2` in class, concatenate `"Data"` and `"Science"` (in that order, no space) into `joined`.

# %%
# YOUR CODE HERE
joined = None

# %%
expected = "DataScience"
assert joined == expected, f"Expected: {expected!r}, got: {joined!r}"
print("Correct! Q11 passed.")

# %% [markdown]
# ## Q12: Iteration
#
# Like the `for i in mystr1:` loop in class, iterate over the string `"Data"` and build a list called `letters` containing each character (e.g. `['D', 'a', 't', 'a']`). Use a `for` loop (not `list(...)`).

# %%
# YOUR CODE HERE
letters = []
# loop here

# %%
expected = ['D', 'a', 't', 'a']
assert letters == expected, f"Expected: {expected!r}, got: {letters!r}"
print("Correct! Q12 passed.")

# %% [markdown]
# ## Q13: strip(), lower(), upper(), title()
#
# Given `text = "   pYTHON proGRAMMING   "`, create four variables:
# - `stripped` — text with leading/trailing whitespace removed
# - `lowered` — the stripped text, all lowercase
# - `uppered` — the stripped text, all uppercase
# - `titled` — the stripped text, in title case

# %%
text = "   pYTHON proGRAMMING   "

# YOUR CODE HERE
stripped = None
lowered = None
uppered = None
titled = None

# %%
assert stripped == "pYTHON proGRAMMING", f"stripped got: {stripped!r}"
assert lowered == "python programming", f"lowered got: {lowered!r}"
assert uppered == "PYTHON PROGRAMMING", f"uppered got: {uppered!r}"
assert titled == "Python Programming", f"titled got: {titled!r}"
print("Correct! Q13 passed.")

# %% [markdown]
# ## Q14: replace() and count()
#
# Given `str2 = "Python Programming"`:
# - Replace `"mm"` with `"Ho"` and store the result in `replaced`
# - Count how many times `"on"` appears in `str2` and store it in `on_count`

# %%
str2 = "Python Programming"

# YOUR CODE HERE
replaced = None
on_count = None

# %%
assert replaced == "Python PrograHoing", f"replaced got: {replaced!r}"
assert on_count == 1, f"on_count got: {on_count!r}"
print("Correct! Q14 passed.")

# %% [markdown]
# ## Q15: startswith() / endswith()
#
# Using `str2 = "Python Programming"`:
# - Set `starts_ok` to whether `str2` starts with `"Python "`
# - Set `ends_ok` to whether `str2` ends with `"ing"`

# %%
# YOUR CODE HERE
starts_ok = None
ends_ok = None

# %%
assert starts_ok is True, f"starts_ok got: {starts_ok!r}"
assert ends_ok is True, f"ends_ok got: {ends_ok!r}"
print("Correct! Q15 passed.")

# %% [markdown]
# ## Q16: split()
#
# Split `str2` (`"Python Programming"`) into a list of words using `.split()` and store it in `words`.

# %%
# YOUR CODE HERE
words = None

# %%
assert words == ["Python", "Programming"], f"Got: {words!r}"
print("Correct! Q16 passed.")

# %% [markdown]
# ## Q17: find()
#
# Like the class example with `str4 = "one two three four five six seven"`, find the index location of the word `"four"` in `str4` and store it in `loc`.

# %%
str4 = "one two three four five six seven"

# YOUR CODE HERE
loc = None

# %%
assert loc == str4.find("four"), f"Expected: {str4.find('four')}, got: {loc!r}"
print("Correct! Q17 passed.")

# %% [markdown]
# ## Q18: isalpha(), isalnum(), isdecimal(), isnumeric()
#
# Given `mystr6 = 'abc12309'`, store the results of the four checks in the corresponding variables below (each should be a boolean).

# %%
mystr6 = 'abc12309'

# YOUR CODE HERE
is_alpha = None
is_alnum = None
is_decimal = None
is_numeric = None

# %%
assert is_alpha is False, f"is_alpha got: {is_alpha!r}"
assert is_alnum is True, f"is_alnum got: {is_alnum!r}"
assert is_decimal is False, f"is_decimal got: {is_decimal!r}"
assert is_numeric is False, f"is_numeric got: {is_numeric!r}"
print("Correct! Q18 passed.")

# %% [markdown]
# ## Q19: isupper() / islower()
#
# Given `mystr7 = 'ABCDEF'`, set `upper_check` and `lower_check` to the results of `.isupper()` and `.islower()`.

# %%
mystr7 = 'ABCDEF'

# YOUR CODE HERE
upper_check = None
lower_check = None

# %%
assert upper_check is True, f"upper_check got: {upper_check!r}"
assert lower_check is False, f"lower_check got: {lower_check!r}"
print("Correct! Q19 passed.")

# %% [markdown]
# ## Q20: The `in` operator
#
# Given `data = "Hello World"`, check whether the substring `"Wor"` is present in `data` and store the boolean result in `answer`.

# %%
data = "Hello World"

# YOUR CODE HERE
answer = None

# %%
assert answer is True, f"Expected: True, got: {answer!r}"
print("Correct! Q20 passed. You've completed all the exercises!")
